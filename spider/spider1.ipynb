# %%
import requests
from bs4 import BeautifulSoup

header = {'User-Agent': 
'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36 Edg/136.0.0.0'}

url = 'https://www.fsc.gov.tw/ch/home.jsp?id=131&parentpath=0,2&qunit=ou=367010000D,ou=organization,o=fsc,c=tw'
r = requests.get(url, headers=header)
soup = BeautifulSoup(r.text, 'html.parser')
r.request.headers


# print(soup) #soup : BeautifulSoup 解析出來的東西
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36 Edg/136.0.0.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
# 以 PTT 熱門看板為例
all_boards = soup.find_all('div', {'class':'b-ent'}) # 找出所有屬性 class 為 b-ent 的 div 標籤，這代表畫面上的每一個板
for board in all_boards: # 遍歷這些板
#     # 找到這個板的第一個屬性 class 為 board-name 的 div 標籤，取其內容(.text)，並存進 name 變數中
    name = board.find('div', {'class':'board-name'}).text

    # 找到這個板的第一個屬性 class 為 board-nuser 的 div 標籤，取其內容(.text)，並存進 user_count 變數中
    user_count = board.find('div', {'class':'board-nuser'}).text

    if int(user_count) >= 1000: # 如果該板人氣大於等於 1000 人
        print(name, user_count) # 就印出板名和人氣值

# %%
import requests
from bs4 import BeautifulSoup

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36'}

url = 'https://www.ccclub.io/course/?course_name=2025Spring'
r = requests.get(url, headers=header)
soup = BeautifulSoup(r.text, 'html.parser')

# %%
print(soup.title)
print(soup.find("title"))
print(soup.title.text)
print(soup.title.string)
# Out:
# <title>ccClub è®æ¸æ</title>
# <title>ccClub è®æ¸æ</title>
# ccClub è®æ¸æ
# ccClub è®æ¸æ

# %%
body = soup.find(('body'))
hw = soup.find(('span'))
print(hw)
# Out:
# None

# %%
from os import listdir
import requests #只能接收到對方伺服器第一次回傳的資料
from bs4 import BeautifulSoup

chrome_version = listdir(r'C:\Program Files\Google\Chrome\Application')[0].split('.')[0]
header = {'User-Agent': f'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/{chrome_version}.0.0.0 Safari/537.36'}
url = 'https://www.twse.com.tw/zh/products/securities/etf/news.html'
r = requests.get(url, headers=header)
r.encoding = 'UTF-8' #指定編碼方式
soup = BeautifulSoup(r.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-Hant-tw">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>ETF 總覽 - TWSE 臺灣證券交易所</title>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <meta content="臺灣證券交易所全球資訊網介紹公司組織、沿革外，並分為「交易資訊」、「上市公司」、 「產品與服務」、「結算服務」、「市場公告」、「法令規章」、「投資人教育」、「統計報表」等，期能提供投資大眾即時完整之訊息，使投資大眾對本公司業務及市場動態有更深一層的瞭解。" name="description"/>
# <meta content="證券,上市,大盤,國際股市指數,匯率,個股行情等,年報,投資,期貨,台灣50,ETF" name="keywords"/>
# <meta content="TWSE" name="author"/>
# <link href="/res/css/web.css" rel="stylesheet"/>
# <meta content="app,wca,web" name="layout">
# <meta content="etf" name="sidebar"/>
# <link href="/res/css/page.css" rel="stylesheet"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-J2HVMN6FVP"></script>
# </meta></head>
# <body class="web">
# <div id="layout">
# ...

# %%
# url = 'https://www.twse.com.tw/rwd/zh/ETFNews/news?response=json&_=1748663876399' 可以刪掉流水號
url = 'https://www.twse.com.tw/rwd/zh/ETFNews/news?response=json' 
r = requests.get(url, headers=header)
r.encoding = 'UTF-8' #指定編碼方式
soup = BeautifulSoup(r.text, 'html.parser')
soup
# Out:
# {"status":"ok","data":[["2025-05-29T05:57:01Z","元大台灣高息低波(00713) 分配收益資訊-公告日期 114年05月29日","https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&amp;firstin=1&amp;TYPEK=all&amp;SKIND=F&amp;SEQ_NO=1&amp;DATE1=20250529&amp;COMP=A00005",null],["2025-05-29T01:34:39Z","統一台灣高息動能(00939) 分配收益資訊-公告日期 114年05月29日","https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&amp;firstin=1&amp;TYPEK=all&amp;SKIND=F&amp;SEQ_NO=1&amp;DATE1=20250529&amp;COMP=A00009",null],["2025-05-23T05:50:10Z","永豐ESG低碳高息(00930) 分配收益資訊-公告日期 114年05月23日","https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&amp;firstin=1&amp;TYPEK=all&amp;SKIND=F&amp;SEQ_NO=2&amp;DATE1=20250523&amp;COMP=A00025",null],["2025-05-23T05:31:48Z","元大台灣價值高息(00940) 分配收益資訊-公告日期 114年05月23日","https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&amp;firstin=1&amp;TYPEK=all&amp;SKIND=F&amp;SEQ_NO=1&amp;DATE1=20250523&amp;COMP=A00005",null],["2025-05-20T01:07:20Z","元大US高息特別股(00771) 分配收益資訊-公告日期 114年05月20日","https://mopsov.twse.com.tw/mops/web
# ...

# %%
import json
data = json.loads(r.text)
data
# Out:
# {'status': 'ok',
#  'data': [['2025-05-29T05:57:01Z',
#    '元大台灣高息低波(00713) 分配收益資訊-公告日期 114年05月29日',
#    'https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&firstin=1&TYPEK=all&SKIND=F&SEQ_NO=1&DATE1=20250529&COMP=A00005',
#    None],
#   ['2025-05-29T01:34:39Z',
#    '統一台灣高息動能(00939) 分配收益資訊-公告日期 114年05月29日',
#    'https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&firstin=1&TYPEK=all&SKIND=F&SEQ_NO=1&DATE1=20250529&COMP=A00009',
#    None],
#   ['2025-05-23T05:50:10Z',
#    '永豐ESG低碳高息(00930) 分配收益資訊-公告日期 114年05月23日',
#    'https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&firstin=1&TYPEK=all&SKIND=F&SEQ_NO=2&DATE1=20250523&COMP=A00025',
#    None],
#   ['2025-05-23T05:31:48Z',
#    '元大台灣價值高息(00940) 分配收益資訊-公告日期 114年05月23日',
#    'https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&firstin=1&TYPEK=all&SKIND=F&SEQ_NO=1&DATE1=20250523&COMP=A00005',
#    None],
#   ['2025-05-20T01:07:20Z',
#    '元大US高息特別股(00771) 分配收益資訊-公告日期 114年05月20日',
# ...

# %%
for i in data['data']:
    print(i)
# Out:
# ['2025-05-29T05:57:01Z', '元大台灣高息低波(00713) 分配收益資訊-公告日期 114年05月29日', 'https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&firstin=1&TYPEK=all&SKIND=F&SEQ_NO=1&DATE1=20250529&COMP=A00005', None]
# ['2025-05-29T01:34:39Z', '統一台灣高息動能(00939) 分配收益資訊-公告日期 114年05月29日', 'https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&firstin=1&TYPEK=all&SKIND=F&SEQ_NO=1&DATE1=20250529&COMP=A00009', None]
# ['2025-05-23T05:50:10Z', '永豐ESG低碳高息(00930) 分配收益資訊-公告日期 114年05月23日', 'https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&firstin=1&TYPEK=all&SKIND=F&SEQ_NO=2&DATE1=20250523&COMP=A00025', None]
# ['2025-05-23T05:31:48Z', '元大台灣價值高息(00940) 分配收益資訊-公告日期 114年05月23日', 'https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&firstin=1&TYPEK=all&SKIND=F&SEQ_NO=1&DATE1=20250523&COMP=A00005', None]
# ['2025-05-20T01:07:20Z', '元大US高息特別股(00771) 分配收益資訊-公告日期 114年05月20日', 'https://mopsov.twse.com.tw/mops/web/ajax_t108sb19?step=2&firstin=1&TYPEK=all&SKIND=F&SEQ_NO=2&DATE1=20250520&COMP=A00005', None]
# ...

# %% [markdown]
# post 請求

# %% [markdown]
# 使用post請求時多了"data"參數要填 變數可以只填一部份(有些保留預設值就可以) 但需要逐個測試才知道

# %%
url = 'https://www.railway.gov.tw/tra-tip-web/tip/tip001/tip112/querybytime'
data = {'startStation':'1000-臺北', 'endStation': '3300-臺中', 'transfer': 'ONE', 
        'rideDate': '2025/06/11', 'startTime': '00:00','endTime': '23:59', 'trainTypeList': 'ALL'}
r = requests.post(url, headers = header, data = data)
soup = BeautifulSoup(r.text, 'html.parser')
soup.select('tbody tr[class="trip-column"] td:nth-child(2)')
# Out:
# [<td>05:24</td>,
#  <td>05:46</td>,
#  <td>06:02</td>,
#  <td>07:00</td>,
#  <td>07:04</td>,
#  <td>07:45</td>,
#  <td>08:00</td>,
#  <td>08:03</td>,
#  <td>08:28</td>,
#  <td>09:00</td>,
#  <td>09:05</td>,
#  <td>10:00</td>,
#  <td>10:20</td>,
#  <td>11:00</td>,
#  <td>11:05</td>,
#  <td>11:58</td>,
#  <td>12:03</td>,
#  <td>12:25</td>,
#  <td>12:48</td>,
#  <td>12:58</td>,
#  <td>13:28</td>,
#  <td>13:47</td>,
#  <td>14:00</td>,
#  <td>15:00</td>,
#  <td>15:10</td>,
#  <td>15:40</td>,
#  <td>15:50</td>,
#  <td>16:00</td>,
#  <td>16:40</td>,
#  <td>17:00</td>,
#  <td>17:28</td>,
#  <td>17:37</td>,
#  <td>18:00</td>,
#  <td>18:24</td>,
#  <td>18:43</td>,
#  <td>18:59</td>,
#  <td>19:30</td>,
#  <td>20:20</td>,
#  <td>21:00</td>]

# %%
soup.select('tbody tr[class="trip-column"] td:nth-child(2)')
# Out:
# [<td>05:24</td>,
#  <td>05:46</td>,
#  <td>06:02</td>,
#  <td>07:00</td>,
#  <td>07:04</td>,
#  <td>07:45</td>,
#  <td>08:00</td>,
#  <td>08:03</td>,
#  <td>08:28</td>,
#  <td>09:00</td>,
#  <td>09:05</td>,
#  <td>10:00</td>,
#  <td>10:20</td>,
#  <td>11:00</td>,
#  <td>11:05</td>,
#  <td>11:58</td>,
#  <td>12:03</td>,
#  <td>12:25</td>,
#  <td>12:48</td>,
#  <td>12:58</td>,
#  <td>13:28</td>,
#  <td>13:47</td>,
#  <td>14:00</td>,
#  <td>15:00</td>,
#  <td>15:10</td>,
#  <td>15:40</td>,
#  <td>15:50</td>,
#  <td>16:00</td>,
#  <td>16:40</td>,
#  <td>17:00</td>,
#  <td>17:28</td>,
#  <td>17:37</td>,
#  <td>18:00</td>,
#  <td>18:24</td>,
#  <td>18:43</td>,
#  <td>18:59</td>,
#  <td>19:30</td>,
#  <td>20:20</td>,
#  <td>21:00</td>]

# %%
# 利用第一種把剛剛抓到的資料定位出來

data = {}
for row in soup.select('tbody tr[class="trip-column"]'):
    #因為要取全部所以取'td li'就好了 用text取純文字 然後把換行符號刪掉(用replace)
    train_number = row.select_one('td li').text.replace('\n', '')
    start_time = row.select('td')[1].text
    end_time = row.select('td')[2].text
    duration = row.select('td')[3].text
    data[train_number] = [train_number, start_time, end_time, duration]
    # break

data
# Out:
# {'區間快 2005(七堵→彰化)': ['區間快 2005(七堵→彰化)', '05:24', '07:55', '2 小時 31 分'],
#  '區間 2133(基隆→嘉義)': ['區間 2133(基隆→嘉義)', '05:46', '09:27', '3 小時 41 分'],
#  '自強(3000) 161(南港→臺東)': ['自強(3000) 161(南港→臺東)', '06:02', '08:03', '2 小時 1 分'],
#  '自強 105(基隆→屏東)': ['自強 105(基隆→屏東)', '07:00', '09:18', '2 小時 18 分'],
#  '區間 2143(基隆→嘉義)': ['區間 2143(基隆→嘉義)', '07:04', '10:20', '3 小時 16 分'],
#  '普悠瑪 107(南港→潮州)': ['普悠瑪 107(南港→潮州)', '07:45', '09:21', '1 小時 36 分'],
#  '自強(3000) 111(七堵→枋寮)': ['自強(3000) 111(七堵→枋寮)', '08:00', '09:49', '1 小時 49 分'],
#  '區間 2153(基隆→嘉義)': ['區間 2153(基隆→嘉義)', '08:03', '11:28', '3 小時 25 分'],
#  '自強 113(七堵→屏東)': ['自強 113(七堵→屏東)', '08:28', '10:39', '2 小時 11 分'],
#  '自強 115(基隆→屏東)': ['自強 115(基隆→屏東)', '09:00', '11:18', '2 小時 18 分'],
#  '區間 2163(基隆→嘉義)': ['區間 2163(基隆→嘉義)', '09:05', '12:21', '3 小時 16 分'],
#  '自強(3000) 131(七堵→潮州)': ['自強(3000) 131(七堵→潮州)', '10:00', '11:49', '1 小時 49 分'],
#  '自強(3000) 117(基隆→潮州)': ['自強(3000) 117(基隆→潮州)', '10:20', '12:24', '2 小時 4 分'],
# ...

# %%
! pip install requests
! pip install beautifulsoup4
! pip install selenium
# Out:
# ...
#   Using cached selenium-4.33.0-py3-none-any.whl.metadata (7.5 kB)
# ...
#   Using cached trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# ...
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# ...
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# ...
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Using cached selenium-4.33.0-py3-none-any.whl (9.4 MB)
# ...

# %% [markdown]
# pandas 爬蟲：read_csv

# %%
import pandas as pd

url = 'https://www.ncc.gov.tw/chinese/files/opendata/%E8%A1%8C%E5%8B%95%E9%80%9A%E4%BF%A1%E6%A5%AD%E5%8B%99%E5%9F%BA%E5%9C%B0%E8%87%BA%E7%B5%B1%E8%A8%88%E6%95%B8(%E5%8D%80%E5%88%86%E7%B8%A3%E5%B8%82%E6%A5%AD%E8%80%85).csv'
df = pd.read_csv(url, header = 0) #headers 指用第幾列資料當表頭
df
# Out:
#         縣市      統計期                                               業者名稱  類別  \
# 0      宜蘭縣  1140531                                         中華電信股份有限公司  4G
# 1      宜蘭縣  1140531  台灣大哥大股份有限公司                                   ...  4G
# 2      宜蘭縣  1140531  遠傳電信股份有限公司                                    ...  4G
# 3      花蓮縣  1140531                                         中華電信股份有限公司  4G
# 4      花蓮縣  1140531  台灣大哥大股份有限公司                                   ...  4G
# ...    ...      ...                                                ...  ..
# 12239  臺北市  1030630                                         中華電信股份有限公司  4G
# 12240  臺北市  1030630                                        台灣大哥大股份有限公司  4G
# 12241  臺北市  1030630                                       台灣之星電信股份有限公司  4G
# 12242  臺北市  1030630                                         遠傳電信股份有限公司  4G
# 12243  臺南市  1030630                                       台灣之星電信股份有限公司  4G
#
#         基地臺
# 0      1036
# 1       664
# 2       692
# 3       996
# ...
